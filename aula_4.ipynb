# %%
import pandas as pd

# %%
import matplotlib

# %%
import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tqdm
#
# ModuleNotFoundError: No module named 'tqdm'
